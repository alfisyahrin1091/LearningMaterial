# %% [markdown]
# # Belajar Python

# %%
10%3
# Out:
# 1

# %%
x = 5
gpa = 3.67
print(x)
print(gpa)
print(x*gpa)
# Out:
# 5
# 3.67
# 18.35

# %%
numb1 = 10
numb2 = 3.4
str1 = 'Indonesia'
b1 = False

print(numb1)
print(numb2)
print(str1)
print(b1)
# Out:
# 10
# 3.4
# Indonesia
# False

# %%
str1 = '100'
str2 = "100.55"
var1 = int(str1)
var2 = float(str2)

print(var1)

a = var1 + 5
b = var2 + 2

print(a)
print(b)
print('hasilnya adalah ', b, 'dan', a, 'selesai')
# Out:
# 100
# 105
# 102.55
# hasilnya adalah  102.55 dan 105 selesai

# %%
b1 = True
b2 = False

print(b1)
print(b2)

var1 = int(b1)
var2 = int(b2)

print(var1)
print(var2)

var3 = 0
b4 = bool(var3)

print(b4)
# Out:
# True
# False
# 1
# 0
# False

# %%
x, y, z = 10, 12, "Alfi"

print('x adalah', x,', ' 'y=', y,', ' 'z =', z)
# Out:
# x adalah 10 , y= 12 , z = Alfi

# %%
if (5 > 2):
  print('hello')
  print('hello word')
  print('helloo')

  # ini adalah komen doang tidak tereksekusi
# Out:
# hello
# hello word
# helloo

# %%
a = input('Berapa umurnya? ')
b = int(a)

print('umurnya adalah', b)
# Out:
# Berapa umurnya? 30
# umurnya adalah 30

# %%
angka1 = input('Angka dalam pikiran anda ')
angka2 = input('Angka yang ada di depan mata anda ')

a = int(angka1)
b = int(angka2)

print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# Angka dalam pikiran anda 5
# Angka yang ada di depan mata anda 2
# 7
# 3
# 10
# 2.5

# %%
a = input('Nama kamu ')
b = input('alamat kamu ')

print("nama saya adalah", a, "alamat saya di", b)
# Out:
# Nama kamu alfi
# alamat kamu depok
# nama saya adalah alfi alamat saya di depok

# %%
str1 = 'belajar '
str2 = 'bahasa pemograman'

str3 = str1 + str2

print(str3)
print(len(str1))
len(str3)

print(str1[2])
print(str1[1:5])
print(str1[:5])
print(str1[2:])
# Out:
# belajar bahasa pemograman
# 8
# l
# elaj
# belaj
# lajar

# %%
str1 = 'belajar bahasa pemorgraman python'
str2 = str1.split(' ')
print(str2)
# Out:
# ['belajar', 'bahasa', 'pemorgraman', 'python']

# %%
str1 = 'belajar bahasa pemograman java'
str2 = str1.replace('java', 'python')

str3 = str1.find('bahasa')

print(str2)
print(str3)
# Out:
# belajar bahasa pemograman python
# 8

# %%
str1 = input('ketik 2 kata ')
str2 = input('kata yang ingin diganti ')
str3 = input('pengganti kata sebelumnya ')

str4= str1.replace(str2, str3)

print(str4)
# Out:
# ketik 2 kata masak air
# kata yang ingin diganti air
# pengganti kata sebelumnya nasi
# masak nasi
